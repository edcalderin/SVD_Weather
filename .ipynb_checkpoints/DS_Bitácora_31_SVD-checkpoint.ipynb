# %% [markdown]
# # Reducción de dimensionalidad - SVD
#
# ### 1. Ejemplo: compresión de una imagen
#
# Vamos a empezar con un ejemplo simple, diferente a los que solemos utilizar. SVD puede ser usado en el contexto de imágenes para comprimir fotos. De esta forma, obtendrás una demostració "visual" del funcionamiento de SVS. En el notebook anterior viste que una imágen (en blanco y negro) es una matriz. Si en lugar de guardar la foto entera (Matriz M de la clase), uno guardase una representación reducida de esta matriz (B) y la manera de pasar de un espacio a otro (V*), entonces se podría ahorrar mucho espacio en el guardado de la foto. Este mismo proceso se utiliza a veces en imágenes y señales para reducir el ruido de las mismas (proceso llamado denoising).
#
# El formalismo de SVD nos asegura que dado el rango que eligamos (r), la foto que podamos reconstruir a partir de B y V* (M moño) será la "mas parecida" posible a la foto original (M)
#
# 1. Primero cargamos la foto. Si no la tienen, deberán bajarse la libreria PIL para hacer este proceso mas fácil.

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
plt.style.use('classic')
img = Image.open('domo_dormido.jpeg')
# convert image to grayscale
imggray = img.convert('LA')
# convert to numpy array
imgmat = np.array(list(imggray.getdata(band=0)), float)
# Reshape according to orginal image dimensions
imgmat.shape = (imggray.size[1], imggray.size[0])

plt.figure(figsize=(9, 6))
plt.imshow(imgmat, cmap='gray')
plt.show()

# %%
imgmat.shape
# Out:
# (960, 1280)

# %% [markdown]
# 2. Vamos a usar la versión clasica del algoritmo de SVD que viene en Numpy (noten que importante que es, que viene por default en Numpy, ya que se usa para muchas más cosas).

# %%
U, D, V = np.linalg.svd(imgmat)

# %% [markdown]
# 3. Inspeccionemos la dimensión de los elementos:

# %%
imgmat.shape
# Out:
# (960, 1280)

# %%
U.shape
# Out:
# (960, 960)

# %%
np.diag(D)
# Out:
# array([[1.39286974e+05, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 2.90584616e+04, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 2.25382304e+04, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         7.44716631e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 4.72092709e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 4.39514052e+00]])

# %%
np.diag(D).shape
# Out:
# (960, 960)

# %%
D.shape
# Out:
# (960,)

# %%
V.shape
# Out:
# (1280, 1280)

# %% [markdown]
# 4. Así como está, si multiplicamos adecuadamente estos tres elementos, recuperariamos la foto original. Veamos que si tomamos los 960 valores singulares tendremos la imagen original nuevamente:

# %%
np.diag(D[:imgmat.shape[0]]).shape
# Out:
# (960, 960)

# %%
reconstimg = np.matrix(U[:, :imgmat.shape[0]]) * np.diag(D[:imgmat.shape[0]]) * np.matrix(V[:imgmat.shape[0], :])
plt.imshow(reconstimg, cmap='gray')
plt.show()

# %% [markdown]
# 5. El objetivo pasa por tomar unicamente los valores singulares más altos. Por una cuestión de comodidad, los valores en D (notar que representa una matriz diagonal pero viene en forma de vector!) ya están ordenados de menor a mayor, siendo los primeros los de mayor valor. Ahora sí, vamos a probar tomando menos valores singulares, empecemos por sólo 3.

# %%
reconstimg = np.matrix(U[:, :3]) * np.diag(D[:3]) * np.matrix(V[:3, :])
plt.imshow(reconstimg, cmap='gray')
plt.show()

# %% [markdown]
# 6. No es muy sorprendente el resultado, pero ya se puede al menos ver que hay un objeto en el centro de la imagen. Para tener tan poca información (sólo los tres vectores propios asociados a los valores propios y los vectores propios) no está tan mal. Ahora si, barramos una cantidad más razonable de valores singulares, y observemos los resultados.

# %%
for i in [5, 10, 15, 20, 30, 50,100]:
    reconstimg = np.matrix(U[:, :i]) * np.diag(D[:i]) * np.matrix(V[:i, :])
    plt.imshow(reconstimg, cmap='gray')
    title = "n = %s" % i
    plt.title(title)
    plt.show()

# %% [markdown]
# ## 2. ¡A probar con un dataset!
#
# Así como hiciste con Clustering, es momento de probar estas técnicas con un dataset de tu elección. Para hacerlo, te recomendamos que mires atentamente la [documentación de Scikit-Learn](https://scikit-learn.org/stable/modules/decomposition.html) y que utilices una implementación de SVD de esa librería, preferiblemente [`TruncatedSVD`](https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.TruncatedSVD.html). Es importante que mires la documentación de esa clase, en particular el ejemplo para comenzar. ¡Ya es hora de aprender solo/a cómo aplicar una herramienta nueva!

# %%
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import pandas as pd
import seaborn as sns

# %%
# Usar dataset a eleccion.
data = pd.read_csv('DS_Bitácora_27_Weather.csv')

# %%
data.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# 1         WNW           44.0        NNW  ...        25.0       1010.6
# 2         WSW           46.0          W  ...        30.0       1007.6
# 3          NE           24.0         SE  ...        16.0       1017.6
# 4           W           41.0        ENE  ...        33.0       1010.8
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# 0       1007.1       8.0       NaN     16.9     21.8         No      0.0
# 1       1007.8       NaN       NaN     17.2     24.3         No      0.0
# 2       1008.7       NaN       2.0     21.0     23.2         No      0.0
# 3       1012.8       NaN       NaN     18.1     26.5         No      1.0
# 4       1006.0       7.0       8.0     17.8     29.7         No      0.2
#
#    RainTomorrow
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No
#
# [5 rows x 24 columns]

# %% [markdown]
# **Preprocesamiento**

# %%
data['RainTomorrow'] = LabelEncoder().fit_transform(data.RainTomorrow)
#Descartando columnas categoricas.
data = data.select_dtypes('number') 
data.drop(columns=['Evaporation', 'Sunshine', 'Cloud9am', 'Cloud3pm'], inplace=True)
data.dropna(inplace=True)

# %%
data.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'WindGustSpeed', 'WindSpeed9am',
#        'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am',
#        'Pressure3pm', 'Temp9am', 'Temp3pm', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
data.shape
# Out:
# (119590, 14)

# %% [markdown]
# **Feature y Target:**

# %%
X, y = data.drop(['RainTomorrow'], axis=1), data.RainTomorrow

# %% [markdown]
# **Reduciendo dimensiones:**

# %%
svd = TruncatedSVD(n_components=3, random_state=42)
data_reduced = svd.fit_transform(X)

# %%
pd.DataFrame(data_reduced)
# Out:
#                   0          1          2
# 0       1427.832063 -19.079563  -2.540514
# 1       1429.038018 -33.867002  -4.521847
# 2       1427.789180 -35.974138   7.893488
# 3       1436.682485 -38.993498 -23.972086
# 4       1430.210338  -6.274942  -8.465159
# ...             ...        ...        ...
# 119585  1448.611694 -20.795513 -17.555992
# 119586  1447.426826 -28.350745 -18.543193
# 119587  1445.738616 -27.045462 -27.210861
# 119588  1442.779074 -28.660357 -15.850596
# 119589  1441.158045 -29.599257 -20.558259
#
# [119590 rows x 3 columns]

# %% [markdown]
# Suma de varianzas

# %%
print('Varianzas', svd.explained_variance_ratio_)
print('Suma de Varianzas', svd.explained_variance_ratio_.sum())
# Out:
# Varianzas [0.06155767 0.46630695 0.18708201]
# Suma de Varianzas 0.714946632514674

# %% [markdown]
# **Arbol de decision (Benchmark):**

# %% [markdown]
# Separando datos en entrenamiento y validacion para modelo benchmark:

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, stratify=y, test_size=.3)

# %% [markdown]
# Creacion de modelo y entrenamiento con datos sin reducir:

# %%
model_benchmark = DecisionTreeClassifier()
model_benchmark.fit(X_train, y_train)
y_train_pred_bench = model_benchmark.predict(X_train)
y_test_pred_bench = model_benchmark.predict(X_test)
score_train_bench = accuracy_score(y_train, y_train_pred_bench)
score_test_bench = accuracy_score(y_test, y_test_pred_bench)
print('Accuracy score en train sin SVD', score_train_bench)
print('Accuracy score en test sin SVD', score_test_bench)
# Out:
# Accuracy score en train sin SVD 1.0
# Accuracy score en test sin SVD 1.0

# %% [markdown]
# **SVD para distintos numeros de columnas y validacion con modelo de clasificacion:**

# %%
variances = []
# De 1 a Columnas -1
cols = np.arange(1, X.shape[1])
scores_test = []
scores_train = []
for i in cols:
    # SVD
    svd_iter = TruncatedSVD(n_components=i, random_state=42)
    X_reduced = svd_iter.fit_transform(X)
    sum_variance = svd_iter.explained_variance_ratio_.sum()
    variances.append(sum_variance)

    # train_test_split de los datos reducidos
    X_train_svd, X_test_svd, y_train_svd, y_test_svd = train_test_split(
        X_reduced, y, stratify=y)
    
    # DecisionTree (Se puede cambiar por otro modelo)
    model_svd = DecisionTreeClassifier().fit(X_train_svd, y_train_svd)
    # Calculando y guardando Accuracy
    score_test = accuracy_score(y_test_svd, model_svd.predict(X_test_svd))
    score_train = accuracy_score(y_train_svd, model_svd.predict(X_train_svd))
    scores_test.append(score_test)
    scores_train.append(score_train)

# %% [markdown]
# **Ploteando resultados**

# %%
plt.figure(figsize=(15, 6))
plt.subplot(1, 2, 1)
plt.title('Varianzas SVD')
plt.xlabel('# Columnas')
plt.ylabel('Suma de varianzas')
plt.scatter(cols, variances, color='black', s=50)
plt.plot(cols, variances, color='purple', linewidth=2)

plt.subplot(1, 2, 2)
plt.xlabel('# Columnas')
plt.ylabel('Accuracy')
plt.title('DecisionTreeClassifier SVD')
plt.plot(cols, scores_test, '-o', label='Test',)
plt.plot(cols, scores_train, '-o', label='Train')
plt.scatter(cols, scores_test, color='black', s=50)
plt.scatter(cols, scores_train, color='black', s=50)
plt.legend(loc='best')
